# %%
import pandas as pd

# self
from GOTools.grpgo import split_cluster

# %%
overlap_mtx = pd.read_csv('./group_go_rate/go_overlap_rate.csv', index_col=0)
print(overlap_mtx.shape)
overlap_mtx.head()
# Out:
# (63, 63)
#                                       extracellular structure organization  \
# extracellular structure organization                                   1.0
# cell cycle                                                             0.0
# sex determination                                                      0.0
# male gamete generation                                                 0.0
# regulation of neuron death                                             0.0
#
#                                       cell cycle  sex determination  \
# extracellular structure organization         0.0                0.0
# cell cycle                                   1.0                0.0
# sex determination                            0.0                1.0
# male gamete generation                       0.0                0.0
# regulation of neuron death                   0.0                0.0
#
#                                       male gamete generation  \
# ...

# %%
split_cluster(overlap_mtx, 10, './overlap_clust')
