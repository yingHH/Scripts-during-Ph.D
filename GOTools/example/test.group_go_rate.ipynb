# %% [markdown]
# # test 'group_go_rate'

# %%
from GOTools.grpgo import group_go_rate

# %%
group_go_rate('./analysis.json', './group_go_rate', 9)
# Out:
# <Numbers of GO Terms>:  63
# <Comparing gene sets to each other ...>
# <Calculating overlap significance by fisher test ...>
# <Done>
#                                                     male sex differentiation  \
# cell surface receptor signaling pathway                                  1.0
# regulation of multicellular organismal development                       1.0
# sex determination                                                        1.0
# ovarian follicle development                                             1.0
# regulation of stem cell differentiation                                  1.0
# ...                                                                      ...
# negative regulation of biological process                                1.0
# regulation of localization                                               1.0
# regulation of response to stimulus                                       1.0
# ...
